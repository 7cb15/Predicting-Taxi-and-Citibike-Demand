# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/projects/ads_csd/shared'

# %%
citi2016 = pd.DataFrame()


file_list = ['201601-citibike-tripdata.csv','201602-citibike-tripdata.csv','201603-citibike-tripdata.csv','201604-citibike-tripdata.csv',
            '201605-citibike-tripdata.csv','201606-citibike-tripdata.csv','201607-citibike-tripdata.csv','201608-citibike-tripdata.csv',
            '201609-citibike-tripdata.csv','201609-citibike-tripdata.csv']

df_list = []

for i in file_list:
    df = pd.read_csv(os.getcwd()+"/dat/"+i)
    df_list.append(df)

citi2016 = pd.concat(df_list)

# %%
citi2016.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           923  1/1/2016 00:00:41  1/1/2016 00:16:04               268
# 1           379  1/1/2016 00:00:45  1/1/2016 00:07:04               476
# 2           589  1/1/2016 00:00:48  1/1/2016 00:10:37               489
# 3           889  1/1/2016 00:01:06  1/1/2016 00:15:56               268
# 4          1480  1/1/2016 00:01:12  1/1/2016 00:25:52              2006
#
#        start station name  start station latitude  start station longitude  \
# 0   Howard St & Centre St               40.719105               -73.999733
# 1         E 31 St & 3 Ave               40.743943               -73.979661
# 2        10 Ave & W 28 St               40.750664               -74.001768
# 3   Howard St & Centre St               40.719105               -73.999733
# 4  Central Park S & 6 Ave               40.765909               -73.976342
#
#    end station id            end station name  end station latitude  \
# ...

# %%
file_list2 = ['201610-citibike-tripdata.csv','201611-citibike-tripdata.csv',
            '201612-citibike-tripdata.csv']

df_list2 = []

for i in file_list2:
    df = pd.read_csv(os.getcwd()+"/dat/"+i)
    df_list2.append(df)

citi2016Q4 = pd.concat(df_list2)

# %%
citi2016Q4.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            328  2016-10-01 00:00:07  2016-10-01 00:05:35               471
# 1            398  2016-10-01 00:00:11  2016-10-01 00:06:49              3147
# 2            430  2016-10-01 00:00:14  2016-10-01 00:07:25               345
# 3            351  2016-10-01 00:00:21  2016-10-01 00:06:12              3307
# 4           2693  2016-10-01 00:00:21  2016-10-01 00:45:15              3428
#
#         Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0  Grand St & Havemeyer St               40.712868               -73.956981
# 1          E 85 St & 3 Ave               40.778012               -73.954071
# 2          W 13 St & 6 Ave               40.736494               -73.997044
# 3   West End Ave & W 94 St               40.794165               -73.974124
# 4          8 Ave & W 16 St               40.740983               -74.001702
#
# ...

# %%
citi2016.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
citi2016Q4.columns = map(str.lower, citi2016Q4.columns)

# %%
citi2016Q4.columns
# Out:
# Index(['trip duration', 'start time', 'stop time', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bike id', 'user type',
#        'birth year', 'gender'],
#       dtype='object')

# %%
citi2016Q4.rename(columns={'trip duration':'tripduration', 'start time':'starttime', 'stop time':'stoptime',
                           'bike id':'bikeid', 'user type':'usertype'},inplace=True)

# %%
citi2016Q4.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
citi_total = pd.concat([citi2016,citi2016Q4])
citi_total.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           923  1/1/2016 00:00:41  1/1/2016 00:16:04               268
# 1           379  1/1/2016 00:00:45  1/1/2016 00:07:04               476
# 2           589  1/1/2016 00:00:48  1/1/2016 00:10:37               489
# 3           889  1/1/2016 00:01:06  1/1/2016 00:15:56               268
# 4          1480  1/1/2016 00:01:12  1/1/2016 00:25:52              2006
#
#        start station name  start station latitude  start station longitude  \
# 0   Howard St & Centre St               40.719105               -73.999733
# 1         E 31 St & 3 Ave               40.743943               -73.979661
# 2        10 Ave & W 28 St               40.750664               -74.001768
# 3   Howard St & Centre St               40.719105               -73.999733
# 4  Central Park S & 6 Ave               40.765909               -73.976342
#
#    end station id            end station name  end station latitude  \
# ...

# %%
citi_total.to_csv('citibike_total2016.csv')
